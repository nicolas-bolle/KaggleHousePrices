# %% [markdown]
# # Kaggle House Prices
#
# This competition: https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/
#
# It is old, and the leaderboard is saturated with perfect submissions. But it looks like great classic ML practice, and I can take inspiration from another submission: https://github.com/sushant2811/KaggleHousingPrices
#
# Here's another resource I should look at: https://towardsdatascience.com/how-to-use-sklearn-pipelines-for-ridiculously-neat-code-a61ab66ca90d
#
# It uses the ColumnTransformer and sklearn's OneHot, which should help streamline my process. My approach isn't fully in the sklearn spirit: the final version should be one pipeline, not preprocessing separate from ML. I'd have to go back and tweak my custom Preprocess class to be more in the right style.
#
# And this could help with better CV: https://scikit-learn.org/stable/auto_examples/model_selection/grid_search_text_feature_extraction.html

# %% [markdown]
# ## Pipeline
#
# 1. Clean variables (without fitting to any data)
#     - Convert obvious candidates for ordinals into ordinals
#     - Process: combine/remove variables as is reasonable, and log1p transform any variables for cost or area
#     - Impute GarageYrBlt which has a natural imputation
# 2. Use the training data to impute and encode
#     - Fit imputers using the training data (median for numeric, mode for ordinal and categorical)
#     - Custom imputer for LotFrontage, which will be a linear function of LotArea
#     - Manual imputer for categoricals, since the SimpleImputer doesn't work on strings
#     - One-hot categoricals (making sure to have the same columns when moving to test data)
#     - Fit a StandardScalar to the data
# 3. Machine learning
#
# I made a preprocessing object to do all of steps 1 and 2

# %% [markdown]
# # Scratchwork

# %%
# Autoreload so we don't have to reimport packages when we change them
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from scipy.stats import norm
from collections import Counter

import houseprice as hp

# %% [markdown]
# ## Preprocessing

# %%
# I'll avoid the names train/test for now, since later on I'll do a train/test split on the known data
data = pd.read_csv('../data/train.csv', index_col='Id')
pred = pd.read_csv('../data/test.csv', index_col='Id')

# %%
# Train/test split
p = 0.2
train, test = train_test_split(data, test_size=int(p*len(data)), random_state=1105)

# %%
# Create and run my preprocessing object
Preprocess = hp.Preprocess()
train = Preprocess.fit_transform(train)

# %%
test = Preprocess.transform(test)

# %%
train.head()
# Out:
#       MSSubClass  LotFrontage   LotArea    Alley  LotShape  LandSlope  \
# Id
# 1270   -0.174147     0.285207  0.432647 -0.26008  0.700356  -0.237743
# 185    -0.174147     0.868101 -0.379610 -0.26008 -1.021783  -0.237743
# 397    -0.886178    -0.464228 -0.442191 -0.26008  0.700356  -0.237743
# 1187    3.148666     1.492630  0.304826 -0.26008 -1.021783   3.190456
# 807     0.537884     0.160301  0.141250 -0.26008  0.700356  -0.237743
#
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd  ...  SaleType_ConLw  \
# Id                                                       ...
# 1270    -0.794792    -0.495581  -0.432168     -1.307673  ...       -0.058621
# 185     -0.794792     2.221970  -2.073382      0.295066  ...       -0.058621
# 397     -0.794792    -0.495581   0.027372     -0.627723  ...       -0.058621
# 1187    -2.244156    -0.495581  -2.335976     -0.724859  ...       -0.058621
# 807     -0.794792    -0.495581  -0.136749     -0.870562  ...       -0.058621
#
# ...

# %%
corrmat = train[Preprocess.numeric + Preprocess.ordinal].corr()
plt.figure(figsize=(15,15))
sns.heatmap(corrmat, square = True)
plt.show()

# %%
# Plot distributions of numeric variables
# Training data in blue, test data in orange
numeric = ['LotFrontage'] + Preprocess.numeric
r = 4
c = 4
fig, axs = plt.subplots(r, c, figsize=(12,12))
plt.subplots_adjust(hspace=0.3)
for i in range(len(numeric)):
    coln = numeric[i]
    axs[i//c,i%c].hist([train[coln],test[coln]], density=True)
    axs[i//c,i%c].set_title(coln)
plt.show()

# %% [markdown]
# ## ML
#
# At the cost of some information leakage, I'll do cross validation with the preprocessed train data above. But recall that the test set was made after fitting on the train set, so there's no information leakage there and the error estimates below will be accurate.

# %%
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
X_train = train.drop(columns='SalePrice')
X_test  = test.drop(columns='SalePrice')
y_train = train['SalePrice']
y_test = test['SalePrice']

# %%
from sklearn.metrics import mean_absolute_error

# Function to simplify measuring error
def error(y1,y2):
    return mean_absolute_error(Preprocess.unscale(y1), Preprocess.unscale(y2))

# %%
lasso = Lasso(alpha=0.01)
lasso.fit(X_train, y_train)
y_lasso = lasso.predict(X_test)

# %%
error(y_test, y_lasso)
# Out:
# 14224.961193676085

# %% [markdown]
# This is already good: the mean absolute error is less than 10% of the mean/median home price.

# %%
14225 / np.mean(Preprocess.unscale(y_test)) * 100
# Out:
# 7.726321156368207

# %% [markdown]
# Now with CV

# %%
lasso_cv = GridSearchCV(Lasso(), {"alpha" : np.logspace(-3,-1.5,20)}, cv=4)
lasso_cv.fit(X_train, y_train)
lasso_cv.best_params_
# Out:
# {'alpha': 0.008858667904100823}

# %%
y_lasso_cv = lasso_cv.predict(X_test)
error(y_test, y_lasso_cv)
# Out:
# 14148.495954136115

# %% [markdown]
# And now random forests for regression

# %%
forest_cv = GridSearchCV(RandomForestRegressor(n_estimators=200), {"max_features" : [30,50,100], "min_samples_leaf" : [1,3,10]})
forest_cv.fit(X_train, y_train)
forest_cv.best_params_
# Out:
# {'max_features': 50, 'min_samples_leaf': 1}

# %%
y_forest_cv = forest_cv.predict(X_test)
error(y_test, y_forest_cv)
# Out:
# 16615.798675950853

# %% [markdown]
# So I'll go with lasso for my first submission

# %%
data = pd.read_csv('../data/train.csv', index_col='Id')
pred = pd.read_csv('../data/test.csv', index_col='Id')

# %%
Preprocess = hp.Preprocess()
data = Preprocess.fit_transform(data)
pred = Preprocess.transform(pred)

# %%
X_train = data.drop(columns='SalePrice')
X_test  = pred.drop(columns='SalePrice')
y_train = data['SalePrice']

# %%
model = Lasso(alpha = 0.008858)
model.fit(X_train, y_train)
y_pred = Preprocess.unscale(model.predict(X_test))

# %%
submission = pd.DataFrame({'Id' : pred.index, 'SalePrice' : y_pred})
submission.head()
# Out:
#      Id      SalePrice
# 0  1461  113040.039012
# 1  1462  156818.344529
# 2  1463  180423.686429
# 3  1464  194952.860281
# 4  1465  204793.732376

# %%
submission.to_csv("0602.csv", index=False)

# %% [markdown]
# Achieved a score of 0.128 on the leaderboard! Apparently back in 2017 the 10th place on the leaderboard was 0.113, so I think I'm doing well; especially for lazy treatment of the categorical values, and not being too careful in variable selection.
#
# Here's a cool way to check my performance: download the leaderboard and visualize it. With some minimum threshold of performance to rule out cheaters.

# %%
house_lb = pd.read_csv('../data/house-prices-advanced-regression-techniques-publicleaderboard.csv')
scores = house_lb['Score']
plt.hist(scores[scores>1])
plt.xlabel('Score')
plt.ylabel('Count')
plt.title('House prices leaderboard, 6/2/22')
plt.show()

# %% [markdown]
# Ok, I don't think this helps. The competition just isn't active enough anymore.
#
# According to this I'm doing really well: https://www.kaggle.com/code/matthiasmatulla/house-prices-leaderboard-what-is-a-good-score/notebook

# %% [markdown]
# # Useful code

# %%
# Sample code
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(LogisticRegression())
grid = {"logisticregression__C" : np.logspace(-6,6,30)}
logreg_cv = GridSearchCV(model, grid, cv=10)
logreg_cv.fit(X_train, y_train)

logreg_cv.best_params_
logreg_cv.best_score_

# %%
from sklearn.neighbors import KernelDensity

n = 1000
b = 0.3

x = np.arange(-3,3,0.1).reshape(-1,1)
y = np.random.normal(size=n).reshape(-1,1)

kde = np.exp(KernelDensity(kernel='gaussian', bandwidth=b).fit(y).score_samples(x))

plt.hist(y, density=True, label='Data')
plt.plot(x, kde, label='KDE')
plt.plot(x, norm.pdf(x, 0, 1))

plt.title('KDE Demo')
plt.legend()
plt.show()

# %%
NA = data.isna().sum()
NA.sort_values(ascending=False, inplace=True)

# %%
NA.head(10)
# Out:
# MasVnrType     8
# MasVnrArea     8
# GarageType     6
# MiscFeature    2
# MSSubClass     0
# Fireplaces     0
# GarageYrBlt    0
# FireplaceQu    0
# Functional     0
# GarageCars     0
# dtype: int64

# %%
# The k features most correlated to a single feature
feat = 'LotFrontage'
k = 10
cols = corrmat.nlargest(k, feat)[feat].index

corrmat = data[cols].corr()
plt.figure(figsize=(8,8))
sns.heatmap(corrmat, square = True)
plt.show()

# %%
# Pairplot
sns.pairplot(data[['GarageArea','GarageQual','GarageCond']])
plt.show()

# %%
# Histogram
aux = data['BsmtFinSF']
plt.hist(aux,bins=100)
plt.show()

# %%
# Histogram with KDE
sns.histplot(data['SalePrice'], kde=True)
plt.show()

# %%
# Tally
Counter(list(data['YrSold']))
# Out:
# Counter({2008: 304, 2007: 329, 2006: 314, 2009: 338, 2010: 175})

# %%
key = next(key for key, val in a.items() if val == value)

# %%
key
# Out:
# 2009

# %%
value = max(a.values())

# %%
# Scatter
data.plot.scatter(x='TotalBsmtSF', y='1stFlrSF')
plt.show()

# %%
# Pairplot
sns.pairplot(data[['BsmtFinSF1','BsmtFinSF2']])
plt.show()

# %% [markdown]
# OverallCond and OverallQual might be too uncorrelated to the obj

# %%
# Categorical/numeric
sns.boxplot(data=data,x='LandContour',y='LandSlope')
# Out:
# <AxesSubplot:xlabel='LandContour', ylabel='LandSlope'>

# %%
# Correlation matrix
plt.figure(figsize=(4,4))
sns.heatmap(data[['SalePrice','BsmtQual','BsmtCond']].corr(), square = True, annot=True)
plt.show()

# %%
# Histogram with Gaussian fit
aux = data['LotFrontage']
vals = aux[~aux.isna()]

# Fit the Gaussian
mu, std = norm.fit(vals)

# Plot the histogram
plt.hist(vals, bins=25, density=True, alpha=0.6, color='g')

# Plot the PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
plt.show()

# %%
# Categorical correlations

# Checking Exterior1st and Exterior2nd correlations
s1 = data['Exterior1st']
s2 = data['Exterior2nd']
categories = np.unique(np.concatenate((np.unique(s1), np.unique(s2))))
n = len(categories)
counts = np.zeros(shape=(n,n))
for i in range(n):
    for j in range(n):
        counts[i,j] = sum((s1 == categories[i]) & (s2 == categories[j]))

# Normalize so each Exterior1st entry has values summing to 1
for i in range(n):
    counts[i,:] = counts[i,:] / np.sum(counts[i,:])
    
# Visualize
sns.heatmap(counts, square = True, annot=True)
plt.show()
# Out:
# C:\Users\NICOLA~1\AppData\Local\Temp/ipykernel_6424/745848891.py:15: RuntimeWarning: invalid value encountered in true_divide
#   counts[i,:] = counts[i,:] / np.sum(counts[i,:])
